# %% [markdown]
# # UNIT 1 Data Preprocessing Exam
# ### Team of 3 students per project

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="https://c.tenor.com/eG9Ro44EyMcAAAAC/our-solar-system-planetary-system.gif" alt="Heat beating" style="height:366px;margin-top:3rem;"> </div>

# %% [markdown]
# # <span style='color:aliceblue'><center style='background:#000000;border-radius:0px 25px;padding:25px'> ☀🌎EDA : Solar System 🌕🪐</center></span>

# %% [markdown]
# # **<span style="color:#E94560;">📰About the Dataset</span>**
#
# In this Dataset, we have various different parameters for 8 different Solar Planets like Name of the Planet, Color, Mass, Diameter, Density, Gravity, Escape Velocity, Rotation Period, Length of Day, Distance from Sun, Perihelion, Aphelion, Orbital Period, Orbital Velocity, Orbital Inclination, Orbital Eccentricity, Obliquity to Orbit, Mean Temperature, Surface Pressure, Number of Moons, Ring System?, Global Magnetic Field?
#
# **Name** - Name of of the Planet.
#
# **Color** - Color of of the Planet.
#
# **Mass (10^24kg)** - This is the mass of the planet in septillion (1 followed by 24 zeros) kilograms or sextillion (1 followed by 21 zeros) tons. Strictly speaking, tons are measures of weight, not mass, but are used here to represent the mass of one ton of material under Earth gr gravity.
#
# **Diameter (km)** - The diameter of the planet at the equator, the distance through the center of the planet from one point on the equator to the opposite side, in kilometers or miles.
#
# **Density (kg/m^3)** - The average density (mass divided by volume) of the whole planet (not including the atmosphere for the terrestrial planets) in kilograms per cubic meter or pounds per cubic foot. Strictly speaking, pounds are measures of weight, not mass, but are used here to represent the mass of one pound of material under Earth's gravity.
#
# **Gravity (m/s^2)** - The gravitational acceleration on the surface at the equator in meters per second squared or feet per second squared, including the effects of rotation. For the gas giant planets, the gravity is given at the 1 bar pressure level in the atmosphere. The gravity on Earth is designated as 1 "G", so the Earth ratio fact sheets give the gravity of the other planets in G's.
#
# **Escape Velocity (km/s)** - Initial velocity, in kilometers per second or miles per second, needed at the surface (at the 1 bar pressure level for the gas giants) to escape the body's gravitational pull, ignoring atmospheric drag.
#
# **Rotation Period (hours)** - This is the time it takes for the planet to complete one rotation relative to the fixed background stars (not relative to the Sun) in hours. Negative numbers indicate retrograde (backward relative to the Earth) rotation.
#
# **Length of Day (hours)** - The average time in hours for the Sun to move from the noon position in the sky at a point on the equator back to the same position.
#
# **Distance from Sun (10^6 km)** - This is the average distance from the planet to the Sun in millions of kilometers or millions of miles, also known as the semi-major axis. All planets have orbits whic are elliptical, not perfectly circular, so there is a point in the orbit at which the planet is closest to the Sun, the perihelion, and a point furthest from the Sun, the aphelion. The average distance from the Sun is midway between these two values. The average distance from the Earth to the Sun is defined as 1 Astronomical Unit (AU), so the ratio table gives this distance in AU.
#
# **Perihelion, Aphelion (10^6 km)** - The closest and furthest points in a planet's orbit about the Sun, see "Distance from Sun" above.
#
# **Orbital Period (days)** - This is the time in Earth days for a planet to orbit the Sun from one vernal equinox to the next. Also known as the tropical orbit period, this is equal to a year on Earth.
#
# **Orbital Velocity (km/s)** - The average velocity or speed of the planet as it orbits the Sun, in kilometers per second or miles per second.
#
# **Orbital Inclination (degrees)** - The angle in degrees at which a planet's orbit around the Sun is tilted relative to the ecliptic plane. The ecliptic plane is defined as the plane containing the Earth's orbit, so the Earth's inclination is 0.
#
# **Orbital Eccentricity** - This is a measure of how far a planet's orbit about the Sun (or the Moon's orbit about the Earth) is from being circular. The larger the eccentricity, the more elongated the orbit, an eccentricity of 0 means the orbit is a perfect circle. There are no units for eccentricity.
#
# **Obliquity to Orbit (degrees)** - The angle in degrees the axis of a planet (the imaginary line running through the center of the planet from the north to south poles) is tilted relative to a line perpendicular to the planet's orbit around the Sun, north pole defined by the right-hand rule. Venus rotates in a retrograde direction, opposite the other planets, so the tilt is almost 180 degrees, it is considered to be spinning with its "top", or north pole pointing "downward" (southward). Uranus rotates almost on its side relative to the orbit, Pluto is pointing slightly "down". The ratios with Earth refer to the axis without reference to north or south.
#
# **Mean Temperature (C)** - This is the average temperature over the whole planet's surface (or for the gas giants at the one bar level) in degrees C (Celsius or Centigrade) or degrees F (Fahrenheit). For Mercury and the Moon, for example, this is an average over the sunlit (very hot) and dark (very cold) hemispheres and so is not representative of any given region on the planet, and most of the surface is quite different from this average value. As with the Earth, there will tend to be variations in temperature from the equator to the poles, from the day to night sides, and seasonal changes on most planets.
#
# **Surface Pressure (bars)** - This is the atmospheric pressure (the weight of the atmosphere per unit area) at the surface of the planet in bars or atmospheres. The surfaces of Jupiter, Saturn, Uranus, and Neptune are deep in the atmosphere and the location and pressures are not known.
#
# **Number of Moons** - This gives the number of IAU officially confirmed moons orbiting the planet. New moons are still being discovered.
#
# **Ring System?** - This tells whether a planet has a set of rings around it, Saturn being the most obvious example.
#
# **Global Magnetic Field?** - This tells whether the planet has a measurable large-scale magnetic field. Mars and the Moon have localized regional magnetic fields but no global field.
#
# **Note: The term "terrestrial planets" refers to Mercury, Venus, Earth, Moon, Mars and the term "gas giants" refers to Jupiter, Saturn, Uranus, Neptune.**

# %%
#imports numpy pandas matplotlib seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Environment check
# Import OS
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **<span style="color:#E94560;">📄Explore Data</span>**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Read `planets.csv`. Do you see anything wrong?

# %%
# Read the csv file and create a DF
planets = pd.read_csv('planets.csv')
planets
# Out:
#    Basura1                                          Basura2         Basura3  \
# 0   Planet                                            Color  Mass (10^24kg)
# 1  Mercury                                             Grey            0.33
# 2    Venus                                   Brown and Grey            4.87
# 3    Earth                      Blue, Brown Green and White            5.97
# 4     Mars                               Red, Brown and Tan           0.642
# 5  Jupiter  Brown, Orange and Tan, with White cloud stripes            1898
# 6   Saturn                     Golden, Brown, and Blue-Grey             568
# 7   Uranus                                       Blue-Green            86.8
# 8  Neptune                                             Blue             102
#
#          Basura4           Basura5                 Basura6  \
# 0  Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)
# 1           4879              5429                     3.7
# 2          12104              5243                     8.9
# 3          12756              5514                     9.8
# 4           6792              3934                     3.7
# 5         142984              1326                    23.1
# 6         120536               687                       9
# 7          51118              1270                     8.7
# 8          49528              1638                      11
#
#                   Basura7                  Basura8                Basura9  \
# 0  Escape Velocity (km/s)  Rotation Period (hours)  Length of Day (hours)
# 1                     4.3                   1407.6                 4222.6
# 2                    10.4                  -5832.5                   2802
# 3                    11.2                     23.9                     24
# 4                       5                     24.6                   24.7
# 5                    59.5                      9.9                    9.9
# 6                    35.5                     10.7                   10.7
# 7                    21.3                    -17.2                   17.2
# 8                    23.5                     16.1                   16.1
#
#                       Basura10  ...               Basura13  \
# 0  Distance from Sun (10^6 km)  ...  Orbital Period (days)
# 1                         57.9  ...                     88
# 2                        108.2  ...                  224.7
# 3                        149.6  ...                  365.2
# 4                          228  ...                    687
# 5                        778.5  ...                   4331
# 6                         1432  ...                 10,747
# 7                         2867  ...                 30,589
# 8                         4515  ...                 59,800
#
#                   Basura14                       Basura15  \
# 0  Orbital Velocity (km/s)  Orbital Inclination (degrees)
# 1                     47.4                              7
# 2                       35                            3.4
# 3                     29.8                              0
# 4                     24.1                            1.8
# 5                     13.1                            1.3
# 6                      9.7                            2.5
# 7                      6.8                            0.8
# 8                      5.4                            1.8
#
#                Basura16                      Basura17              Basura18  \
# 0  Orbital Eccentricity  Obliquity to Orbit (degrees)  Mean Temperature (C)
# 1                 0.206                         0.034                   167
# 2                 0.007                         177.4                   464
# 3                 0.017                          23.4                    15
# 4                 0.094                          25.2                   -65
# 5                 0.049                           3.1                  -110
# 6                 0.052                          26.7                  -140
# 7                 0.047                          97.8                  -195
# 8                  0.01                          28.3                  -200
#
#                   Basura19         Basura20      Basura21  \
# 0  Surface Pressure (bars)  Number of Moons  Ring System?
# 1                        0                0            No
# 2                       92                0            No
# 3                        1                1            No
# 4                     0.01                2            No
# 5                  Unknown               79           Yes
# 6                  Unknown               82           Yes
# 7                  Unknown               27           Yes
# 8                  Unknown               14           Yes
#
#                  Basura22
# 0  Global Magnetic Field?
# 1                     Yes
# 2                      No
# 3                     Yes
# 4                      No
# 5                     Yes
# 6                     Yes
# 7                     Yes
# 8                     Yes
#
# [9 rows x 22 columns]

# %% [markdown]
# Ignore the first row to get the correct headers and then print the DF data

# %%
planets = pd.read_csv('planets.csv', skiprows=1)
planets
# Out:
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
# 5   Saturn                     Golden, Brown, and Blue-Grey         568.000
# 6   Uranus                                       Blue-Green          86.800
# 7  Neptune                                             Blue         102.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# 3           6792              3934                     3.7
# 4         142984              1326                    23.1
# 5         120536               687                     9.0
# 6          51118              1270                     8.7
# 7          49528              1638                    11.0
#
#    Escape Velocity (km/s)  Rotation Period (hours)  Length of Day (hours)  \
# 0                     4.3                   1407.6                 4222.6
# 1                    10.4                  -5832.5                 2802.0
# 2                    11.2                     23.9                   24.0
# 3                     5.0                     24.6                   24.7
# 4                    59.5                      9.9                    9.9
# 5                    35.5                     10.7                   10.7
# 6                    21.3                    -17.2                   17.2
# 7                    23.5                     16.1                   16.1
#
#    Distance from Sun (10^6 km)  ...  Orbital Period (days)  \
# 0                         57.9  ...                     88
# 1                        108.2  ...                  224.7
# 2                        149.6  ...                  365.2
# 3                        228.0  ...                    687
# 4                        778.5  ...                   4331
# 5                       1432.0  ...                 10,747
# 6                       2867.0  ...                 30,589
# 7                       4515.0  ...                 59,800
#
#    Orbital Velocity (km/s) Orbital Inclination (degrees)  \
# 0                     47.4                           7.0
# 1                     35.0                           3.4
# 2                     29.8                           0.0
# 3                     24.1                           1.8
# 4                     13.1                           1.3
# 5                      9.7                           2.5
# 6                      6.8                           0.8
# 7                      5.4                           1.8
#
#    Orbital Eccentricity  Obliquity to Orbit (degrees)  Mean Temperature (C)  \
# 0                 0.206                         0.034                   167
# 1                 0.007                       177.400                   464
# 2                 0.017                        23.400                    15
# 3                 0.094                        25.200                   -65
# 4                 0.049                         3.100                  -110
# 5                 0.052                        26.700                  -140
# 6                 0.047                        97.800                  -195
# 7                 0.010                        28.300                  -200
#
#    Surface Pressure (bars)  Number of Moons Ring System?  \
# 0                        0                0           No
# 1                       92                0           No
# 2                        1                1           No
# 3                     0.01                2           No
# 4                  Unknown               79          Yes
# 5                  Unknown               82          Yes
# 6                  Unknown               27          Yes
# 7                  Unknown               14          Yes
#
#    Global Magnetic Field?
# 0                     Yes
# 1                      No
# 2                     Yes
# 3                      No
# 4                     Yes
# 5                     Yes
# 6                     Yes
# 7                     Yes
#
# [8 rows x 22 columns]

# %% [markdown]
# Check the DF information

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Planet                         8 non-null      object
#  1   Color                          8 non-null      object
#  2   Mass (10^24kg)                 8 non-null      float64
#  3   Diameter (km)                  8 non-null      int64
#  4   Density (kg/m^3)               8 non-null      int64
#  5   Surface Gravity(m/s^2)         8 non-null      float64
#  6   Escape Velocity (km/s)         8 non-null      float64
#  7   Rotation Period (hours)        8 non-null      float64
#  8   Length of Day (hours)          8 non-null      float64
#  9   Distance from Sun (10^6 km)    8 non-null      float64
#  10  Perihelion (10^6 km)           8 non-null      float64
#  11  Aphelion (10^6 km)             8 non-null      float64
#  12  Orbital Period (days)          8 non-null      object
#  13  Orbital Velocity (km/s)        8 non-null      float64
#  14  Orbital Inclination (degrees)  8 non-null      float64
#  15  Orbital Eccentricity           8 non-null      float64
#  16  Obliquity to Orbit (degrees)   8 non-null      float64
#  17  Mean Temperature (C)           8 non-null      int64
#  18  Surface Pressure (bars)        8 non-null      object
#  19  Number of Moons                8 non-null      int64
#  20  Ring System?                   8 non-null      object
#  21  Global Magnetic Field?         8 non-null      object
# dtypes: float64(12), int64(4), object(6)
# memory usage: 1.5+ KB

# %% [markdown]
# Get some statistical numbers

# %%
planets.describe()
# Out:
#        Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# count        8.000000       8.000000          8.000000
# mean       333.326500   50087.125000       3130.125000
# std        660.538057   53916.366175       2104.022368
# min          0.330000    4879.000000        687.000000
# 25%          3.813000   10776.000000       1312.000000
# 50%         46.385000   31142.000000       2786.000000
# 75%        218.500000   68472.500000       5289.500000
# max       1898.000000  142984.000000       5514.000000
#
#        Surface Gravity(m/s^2)  Escape Velocity (km/s)  \
# count                8.000000                 8.00000
# mean                 9.737500                21.33750
# std                  6.040089                18.67473
# min                  3.700000                 4.30000
# 25%                  7.450000                 9.05000
# 50%                  8.950000                16.25000
# 75%                 10.100000                26.50000
# max                 23.100000                59.50000
#
#        Rotation Period (hours)  Length of Day (hours)  \
# count                 8.000000                8.00000
# mean               -544.612500              890.90000
# std                2191.819718             1661.92169
# min               -5832.500000                9.90000
# 25%                   3.125000               14.75000
# 50%                  13.400000               20.60000
# 75%                  24.075000              719.02500
# max                1407.600000             4222.60000
#
#        Distance from Sun (10^6 km)  Perihelion (10^6 km)  Aphelion (10^6 km)  \
# count                     8.000000              8.000000            8.000000
# mean                   1267.025000           1226.162500         1307.912500
# std                    1626.047146           1599.115396         1653.781713
# min                      57.900000             46.000000           69.800000
# 25%                     139.250000            137.200000          141.300000
# 50%                     503.250000            473.650000          532.850000
# 75%                    1790.750000           1701.375000         1880.225000
# max                    4515.000000           4471.100000         4558.900000
#
#        Orbital Velocity (km/s)  Orbital Inclination (degrees)  \
# count                 8.000000                       8.000000
# mean                 21.412500                       2.325000
# std                  15.183397                       2.150581
# min                   5.400000                       0.000000
# 25%                   8.975000                       1.175000
# 50%                  18.600000                       1.800000
# 75%                  31.100000                       2.725000
# max                  47.400000                       7.000000
#
#        Orbital Eccentricity  Obliquity to Orbit (degrees)  \
# count              8.000000                      8.000000
# mean               0.060250                     47.741750
# std                0.065447                     60.364836
# min                0.007000                      0.034000
# 25%                0.015250                     18.325000
# 50%                0.048000                     25.950000
# 75%                0.062500                     45.675000
# max                0.206000                    177.400000
#
#        Mean Temperature (C)  Number of Moons
# count              8.000000         8.000000
# mean              -8.000000        25.625000
# std              225.783714        35.136215
# min             -200.000000         0.000000
# 25%             -153.750000         0.750000
# 50%              -87.500000         8.000000
# 75%               53.000000        40.000000
# max              464.000000        82.000000

# %% [markdown]
# Get column names

# %%
planets.columns
# Out:
# Index(['Planet', 'Color', 'Mass (10^24kg)', 'Diameter (km)',
#        'Density (kg/m^3)', 'Surface Gravity(m/s^2)', 'Escape Velocity (km/s)',
#        'Rotation Period (hours)', 'Length of Day (hours)',
#        'Distance from Sun (10^6 km)', 'Perihelion (10^6 km)',
#        'Aphelion (10^6 km)', 'Orbital Period (days)',
#        'Orbital Velocity (km/s)', 'Orbital Inclination (degrees)',
#        'Orbital Eccentricity', 'Obliquity to Orbit (degrees)',
#        'Mean Temperature (C)', 'Surface Pressure (bars)', 'Number of Moons',
#        'Ring System?', 'Global Magnetic Field?'],
#       dtype='object')

# %% [markdown]
# Get how many rows and columns are there?

# %%
planets.shape
# Out:
# (8, 22)

# %% [markdown]
# Do we have any missing data?
# Give me number and percentages.

# %%
planets.isnull().sum()*100/len(planets)
# Out:
# Planet                           0.0
# Color                            0.0
# Mass (10^24kg)                   0.0
# Diameter (km)                    0.0
# Density (kg/m^3)                 0.0
# Surface Gravity(m/s^2)           0.0
# Escape Velocity (km/s)           0.0
# Rotation Period (hours)          0.0
# Length of Day (hours)            0.0
# Distance from Sun (10^6 km)      0.0
# Perihelion (10^6 km)             0.0
# Aphelion (10^6 km)               0.0
# Orbital Period (days)            0.0
# Orbital Velocity (km/s)          0.0
# Orbital Inclination (degrees)    0.0
# Orbital Eccentricity             0.0
# Obliquity to Orbit (degrees)     0.0
# Mean Temperature (C)             0.0
# Surface Pressure (bars)          0.0
# Number of Moons                  0.0
# Ring System?                     0.0
# Global Magnetic Field?           0.0
# dtype: float64

# %% [markdown]
# Visualize the missing data if there is any?

# %%
planets.isna().sum()
# Out:
# Planet                           0
# Color                            0
# Mass (10^24kg)                   0
# Diameter (km)                    0
# Density (kg/m^3)                 0
# Surface Gravity(m/s^2)           0
# Escape Velocity (km/s)           0
# Rotation Period (hours)          0
# Length of Day (hours)            0
# Distance from Sun (10^6 km)      0
# Perihelion (10^6 km)             0
# Aphelion (10^6 km)               0
# Orbital Period (days)            0
# Orbital Velocity (km/s)          0
# Orbital Inclination (degrees)    0
# Orbital Eccentricity             0
# Obliquity to Orbit (degrees)     0
# Mean Temperature (C)             0
# Surface Pressure (bars)          0
# Number of Moons                  0
# Ring System?                     0
# Global Magnetic Field?           0
# dtype: int64

# %% [markdown]
# Create a correlation.

# %%
# To find the correlation among
# the columns using pearson method
planets.corr(method="pearson")
# Out:
#                                Mass (10^24kg)  Diameter (km)  \
# Mass (10^24kg)                       1.000000       0.866097
# Diameter (km)                        0.866097       1.000000
# Density (kg/m^3)                    -0.524210      -0.817005
# Surface Gravity(m/s^2)               0.894167       0.768295
# Escape Velocity (km/s)               0.933021       0.966658
# Rotation Period (hours)              0.143027       0.190506
# Length of Day (hours)               -0.303537      -0.474477
# Distance from Sun (10^6 km)         -0.050107       0.246785
# Perihelion (10^6 km)                -0.053845       0.238853
# Aphelion (10^6 km)                  -0.046468       0.254348
# Orbital Velocity (km/s)             -0.359022      -0.649839
# Orbital Inclination (degrees)       -0.205094      -0.279457
# Orbital Eccentricity                -0.108263      -0.243918
# Obliquity to Orbit (degrees)        -0.336294      -0.283127
# Mean Temperature (C)                -0.289213      -0.505672
# Number of Moons                      0.812284       0.981210
#
#                                Density (kg/m^3)  Surface Gravity(m/s^2)  \
# Mass (10^24kg)                        -0.524210                0.894167
# Diameter (km)                         -0.817005                0.768295
# Density (kg/m^3)                       1.000000               -0.479018
# Surface Gravity(m/s^2)                -0.479018                1.000000
# Escape Velocity (km/s)                -0.749640                0.902124
# Rotation Period (hours)               -0.280245               -0.038827
# Length of Day (hours)                  0.637518               -0.396507
# Distance from Sun (10^6 km)           -0.671075                0.149307
# Perihelion (10^6 km)                  -0.660572                0.149355
# Aphelion (10^6 km)                    -0.680923                0.149186
# Orbital Velocity (km/s)                0.918023               -0.454035
# Orbital Inclination (degrees)          0.381882               -0.428994
# Orbital Eccentricity                   0.297387               -0.446587
# Obliquity to Orbit (degrees)           0.175433               -0.134573
# Mean Temperature (C)                   0.766660               -0.253533
# Number of Moons                       -0.792252                0.654836
#
#                                Escape Velocity (km/s)  \
# Mass (10^24kg)                               0.933021
# Diameter (km)                                0.966658
# Density (kg/m^3)                            -0.749640
# Surface Gravity(m/s^2)                       0.902124
# Escape Velocity (km/s)                       1.000000
# Rotation Period (hours)                      0.138669
# Length of Day (hours)                       -0.472598
# Distance from Sun (10^6 km)                  0.245740
# Perihelion (10^6 km)                         0.240281
# Aphelion (10^6 km)                           0.250905
# Orbital Velocity (km/s)                     -0.623479
# Orbital Inclination (degrees)               -0.344955
# Orbital Eccentricity                        -0.311856
# Obliquity to Orbit (degrees)                -0.257993
# Mean Temperature (C)                        -0.461329
# Number of Moons                              0.906272
#
#                                Rotation Period (hours)  Length of Day (hours)  \
# Mass (10^24kg)                                0.143027              -0.303537
# Diameter (km)                                 0.190506              -0.474477
# Density (kg/m^3)                             -0.280245               0.637518
# Surface Gravity(m/s^2)                       -0.038827              -0.396507
# Escape Velocity (km/s)                        0.138669              -0.472598
# Rotation Period (hours)                       1.000000              -0.255546
# Length of Day (hours)                        -0.255546               1.000000
# Distance from Sun (10^6 km)                   0.201472              -0.440272
# Perihelion (10^6 km)                          0.197086              -0.435095
# Aphelion (10^6 km)                            0.205619              -0.445073
# Orbital Velocity (km/s)                      -0.182939               0.834249
# Orbital Inclination (degrees)                 0.007626               0.904967
# Orbital Eccentricity                          0.512631               0.610467
# Obliquity to Orbit (degrees)                 -0.892244               0.228681
# Mean Temperature (C)                         -0.724497               0.781192
# Number of Moons                               0.209872              -0.440879
#
#                                Distance from Sun (10^6 km)  \
# Mass (10^24kg)                                   -0.050107
# Diameter (km)                                     0.246785
# Density (kg/m^3)                                 -0.671075
# Surface Gravity(m/s^2)                            0.149307
# Escape Velocity (km/s)                            0.245740
# Rotation Period (hours)                           0.201472
# Length of Day (hours)                            -0.440272
# Distance from Sun (10^6 km)                       1.000000
# Perihelion (10^6 km)                              0.999750
# Aphelion (10^6 km)                                0.999766
# Orbital Velocity (km/s)                          -0.767213
# Orbital Inclination (degrees)                    -0.301097
# Orbital Eccentricity                             -0.377930
# Obliquity to Orbit (degrees)                     -0.009696
# Mean Temperature (C)                             -0.630283
# Number of Moons                                   0.151051
#
#                                Perihelion (10^6 km)  Aphelion (10^6 km)  \
# Mass (10^24kg)                            -0.053845           -0.046468
# Diameter (km)                              0.238853            0.254348
# Density (kg/m^3)                          -0.660572           -0.680923
# Surface Gravity(m/s^2)                     0.149355            0.149186
# Escape Velocity (km/s)                     0.240281            0.250905
# Rotation Period (hours)                    0.197086            0.205619
# Length of Day (hours)                     -0.435095           -0.445073
# Distance from Sun (10^6 km)                0.999750            0.999766
# Perihelion (10^6 km)                       1.000000            0.999032
# Aphelion (10^6 km)                         0.999032            1.000000
# Orbital Velocity (km/s)                   -0.759807           -0.774018
# Orbital Inclination (degrees)             -0.297266           -0.304660
# Orbital Eccentricity                      -0.380585           -0.375182
# Obliquity to Orbit (degrees)              -0.012218           -0.007249
# Mean Temperature (C)                      -0.622708           -0.637314
# Number of Moons                            0.140872            0.160834
#
#                                Orbital Velocity (km/s)  \
# Mass (10^24kg)                               -0.359022
# Diameter (km)                                -0.649839
# Density (kg/m^3)                              0.918023
# Surface Gravity(m/s^2)                       -0.454035
# Escape Velocity (km/s)                       -0.623479
# Rotation Period (hours)                      -0.182939
# Length of Day (hours)                         0.834249
# Distance from Sun (10^6 km)                  -0.767213
# Perihelion (10^6 km)                         -0.759807
# Aphelion (10^6 km)                           -0.774018
# Orbital Velocity (km/s)                       1.000000
# Orbital Inclination (degrees)                 0.666519
# Orbital Eccentricity                          0.572237
# Obliquity to Orbit (degrees)                  0.070848
# Mean Temperature (C)                          0.800166
# Number of Moons                              -0.595024
#
#                                Orbital Inclination (degrees)  \
# Mass (10^24kg)                                     -0.205094
# Diameter (km)                                      -0.279457
# Density (kg/m^3)                                    0.381882
# Surface Gravity(m/s^2)                             -0.428994
# Escape Velocity (km/s)                             -0.344955
# Rotation Period (hours)                             0.007626
# Length of Day (hours)                               0.904967
# Distance from Sun (10^6 km)                        -0.301097
# Perihelion (10^6 km)                               -0.297266
# Aphelion (10^6 km)                                 -0.304660
# Orbital Velocity (km/s)                             0.666519
# Orbital Inclination (degrees)                       1.000000
# Orbital Eccentricity                                0.775083
# Obliquity to Orbit (degrees)                       -0.043223
# Mean Temperature (C)                                0.520570
# Number of Moons                                    -0.224079
#
#                                Orbital Eccentricity  \
# Mass (10^24kg)                            -0.108263
# Diameter (km)                             -0.243918
# Density (kg/m^3)                           0.297387
# Surface Gravity(m/s^2)                    -0.446587
# Escape Velocity (km/s)                    -0.311856
# Rotation Period (hours)                    0.512631
# Length of Day (hours)                      0.610467
# Distance from Sun (10^6 km)               -0.377930
# Perihelion (10^6 km)                      -0.380585
# Aphelion (10^6 km)                        -0.375182
# Orbital Velocity (km/s)                    0.572237
# Orbital Inclination (degrees)              0.775083
# Orbital Eccentricity                       1.000000
# Obliquity to Orbit (degrees)              -0.454753
# Mean Temperature (C)                       0.114232
# Number of Moons                           -0.161660
#
#                                Obliquity to Orbit (degrees)  \
# Mass (10^24kg)                                    -0.336294
# Diameter (km)                                     -0.283127
# Density (kg/m^3)                                   0.175433
# Surface Gravity(m/s^2)                            -0.134573
# Escape Velocity (km/s)                            -0.257993
# Rotation Period (hours)                           -0.892244
# Length of Day (hours)                              0.228681
# Distance from Sun (10^6 km)                       -0.009696
# Perihelion (10^6 km)                              -0.012218
# Aphelion (10^6 km)                                -0.007249
# Orbital Velocity (km/s)                            0.070848
# Orbital Inclination (degrees)                     -0.043223
# Orbital Eccentricity                              -0.454753
# Obliquity to Orbit (degrees)                       1.000000
# Mean Temperature (C)                               0.579396
# Number of Moons                                   -0.285726
#
#                                Mean Temperature (C)  Number of Moons
# Mass (10^24kg)                            -0.289213         0.812284
# Diameter (km)                             -0.505672         0.981210
# Density (kg/m^3)                           0.766660        -0.792252
# Surface Gravity(m/s^2)                    -0.253533         0.654836
# Escape Velocity (km/s)                    -0.461329         0.906272
# Rotation Period (hours)                   -0.724497         0.209872
# Length of Day (hours)                      0.781192        -0.440879
# Distance from Sun (10^6 km)               -0.630283         0.151051
# Perihelion (10^6 km)                      -0.622708         0.140872
# Aphelion (10^6 km)                        -0.637314         0.160834
# Orbital Velocity (km/s)                    0.800166        -0.595024
# Orbital Inclination (degrees)              0.520570        -0.224079
# Orbital Eccentricity                       0.114232        -0.161660
# Obliquity to Orbit (degrees)               0.579396        -0.285726
# Mean Temperature (C)                       1.000000        -0.480981
# Number of Moons                           -0.480981         1.000000

# %% [markdown]
# Make a heat map.

# %%
#Remember to use Seaborn.
fig, ax = plt.subplots(figsize=(15,8))
sns.heatmap(planets.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Visualize the numeric columns histogram.

# %%
planets.hist(figsize=(25,25))
# Out:
# array([[<AxesSubplot:title={'center':'Mass (10^24kg)'}>,
#         <AxesSubplot:title={'center':'Diameter (km)'}>,
#         <AxesSubplot:title={'center':'Density (kg/m^3)'}>,
#         <AxesSubplot:title={'center':'Surface Gravity(m/s^2)'}>],
#        [<AxesSubplot:title={'center':'Escape Velocity (km/s)'}>,
#         <AxesSubplot:title={'center':'Rotation Period (hours)'}>,
#         <AxesSubplot:title={'center':'Length of Day (hours)'}>,
#         <AxesSubplot:title={'center':'Distance from Sun (10^6 km)'}>],
#        [<AxesSubplot:title={'center':'Perihelion (10^6 km)'}>,
#         <AxesSubplot:title={'center':'Aphelion (10^6 km)'}>,
#         <AxesSubplot:title={'center':'Orbital Velocity (km/s)'}>,
#         <AxesSubplot:title={'center':'Orbital Inclination (degrees)'}>],
#        [<AxesSubplot:title={'center':'Orbital Eccentricity'}>,
#         <AxesSubplot:title={'center':'Obliquity to Orbit (degrees)'}>,
#         <AxesSubplot:title={'center':'Mean Temperature (C)'}>,
#         <AxesSubplot:title={'center':'Number of Moons'}>]], dtype=object)

# %% [markdown]
# Do a scatter matrix for the following columns
# ```
# ['Mass (10^24kg)', 'Diameter (km)',
#        'Density (kg/m^3)', 'Surface Gravity(m/s^2)', 'Escape Velocity (km/s)',
#        'Rotation Period (hours)', 'Length of Day (hours)',
#        'Distance from Sun (10^6 km)', 'Orbital Period (days)',
#        'Orbital Velocity (km/s)']
# ```

# %%
sns.pairplot(planets)

# %% [markdown]
# ## **<span style="color:#E94560;">👀Let's Analyse</span>**

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Distance of Planets from Sun (in 10^6 km) </span>**

# %% [markdown]
# Create a plot(graph) to visualize the distance fro mthe sun from the closets to the fatherts.

# %%
# Crea a plot a NICE one with labels, title
def plotsss(x,y,title):
    sns.barplot(x = x, y = y)
    plt.title(title)
plotsss(planets['Planet'], planets['Distance from Sun (10^6 km)'], 'Distance to the sun')

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs Mass </span>**

# %%
plotsss(planets['Planet'],planets['Mass (10^24kg)'], 'Mass')

# %% [markdown]
# **Note:** The planets with large masses are all gas giants - Jupiter, Saturn, Uranus and Neptune

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs their Diameter </span>**

# %%
plotsss(planets['Planet'],planets['Diameter (km)'], 'Diameter of the planets')

# %% [markdown]
# **Note:** From above 2 plots we can say, that higher the mass of a planet higher is the diameter.

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs their Surface Gravity </span>**

# %%
plotsss(planets['Planet'],planets['Surface Gravity(m/s^2)'], 'Surface gravity')

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs their Rotation Period</span>**

# %%
sns.lineplot(data = planets, x = 'Planet', y='Rotation Period (hours)')
plt.title('Rotation Period')
# Out:
# Text(0.5, 1.0, 'Rotation Period')

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs their Number of Moons</span>**

# %%
plotsss(planets['Planet'],planets['Number of Moons'], 'Number of moons')

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs their Mean Temperature (C)</span>**

# %%
sns.lineplot(data = planets, x = 'Planet', y='Mean Temperature (C)')
plt.title('Temperature')
# Out:
# Text(0.5, 1.0, 'Temperature')

# %% [markdown]
# ## **<span style="color:#9C2C77;">🌟Planets Vs Length of Day (hours)</span>**

# %%
plotsss(planets['Planet'],planets['Length of Day (hours)'], 'Length of Day')

# %% [markdown]
# **Note:** The Planets closest to sun have longer days as compared to planets far away.

# %% [markdown]
# Print the `Perihelion, Aphelion (10^6 km)` for each `planet`.

# %%
planets.iloc[:, [0,10,11]]
# Out:
#     Planet  Perihelion (10^6 km)  Aphelion (10^6 km)
# 0  Mercury                  46.0                69.8
# 1    Venus                 107.5               108.9
# 2    Earth                 147.1               152.1
# 3     Mars                 206.7               249.3
# 4  Jupiter                 740.6               816.4
# 5   Saturn                1357.6              1506.5
# 6   Uranus                2732.7              3001.4
# 7  Neptune                4471.1              4558.9

# %% [markdown]
# Print the `Orbital Inclination (degrees)` for each planet

# %%
planets.iloc[:, [0,14]]
# Out:
#     Planet  Orbital Inclination (degrees)
# 0  Mercury                            7.0
# 1    Venus                            3.4
# 2    Earth                            0.0
# 3     Mars                            1.8
# 4  Jupiter                            1.3
# 5   Saturn                            2.5
# 6   Uranus                            0.8
# 7  Neptune                            1.8

# %% [markdown]
# Which planets have the `Surface Gravity(m/s^2)` greater than EARTH?

# %%
gravity = planets.iloc[:, [0,5]]
grav = gravity.loc[gravity['Surface Gravity(m/s^2)'] > 9.8]
grav
# Out:
#     Planet  Surface Gravity(m/s^2)
# 4  Jupiter                    23.1
# 7  Neptune                    11.0

# %% [markdown]
# What is the most repeated colors for all planets?
# Use the Color column to get the information. split the colors by commas",".

# %%
# Write your code here

# %%
# Plot you bar graph here
